# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import pydeck as pdk
import folium
from folium.plugins import HeatMap

# %%
df = pd.read_csv('GTD.csv')

# %%
df = df[df['country_txt'] == 'Israel']
df=df[['latitude', 'longitude', 'nkill']].dropna()
df['nkill'] = df['nkill'].astype(int)
df['attack_indicator'] = 1

# %%
print(df)
# Out:
#          latitude  longitude  nkill  attack_indicator
# 1014    31.771599  35.203400      1                 1
# 1314    32.004361  34.888229     26                 1
# 1498    31.771599  35.203400      0                 1
# 1499    31.771599  35.203400      0                 1
# 1500    31.771599  35.203400      0                 1
# ...           ...        ...    ...               ...
# 208201  31.670149  34.575154      0                 1
# 208772  33.015585  35.784354      0                 1
# 208854  31.670149  34.575154      0                 1
# 208984  31.927682  34.797671      0                 1
# 209568  31.670149  34.575154      0                 1
#
# [2021 rows x 4 columns]

# %%
kill_frequencies = df['nkill'].value_counts().sort_index()
print(kill_frequencies)
# Out:
# nkill
# 0     1595
# 1      203
# 2       71
# 3       29
# 4       31
# 5       17
# 6       14
# 7        9
# 8        9
# 9        4
# 10       4
# 11       3
# 12       4
# 13       1
# 14       1
# 15       4
# 16       4
# 17       2
# 18       1
# 19       2
# 20       2
# 21       2
# 22       1
# 23       2
# 24       1
# 25       1
# 26       2
# 31       1
# 42       1
# Name: count, dtype: int64

# %%
layer = pdk.Layer(
    "GridLayer",
    df,
    pickable=True,
    extruded=True, 
    cell_size=4000,  
    elevation_scale=90, 
    get_position=["longitude", "latitude"], 
    get_elevation="nkill",  
    elevation_range=[0, 3000], 
)

# %%
layer = pdk.Layer(
    "GridLayer",
    df,
    pickable=True,
    extruded=True, 
    cell_size=4000,  
    elevation_scale=90, 
    get_position=["longitude", "latitude"], 
    get_elevation="attack_indicator",  
    elevation_range=[0, 3000], 
)

# %%
layer = pdk.Layer(
    "HeatmapLayer",      
    df,                  
    get_position=['longitude', 'latitude'],
    get_weight= "nkill", 
    radius_pixels=60,    
    opacity=0.9          
)

# %%
layer = pdk.Layer(
    "HeatmapLayer",      
    df,                  
    get_position=['longitude', 'latitude'],
    get_weight= "attack_indicator", 
    radius_pixels=60,    
    opacity=0.9          
)

# %%
layer = pdk.Layer(
    "ScatterplotLayer", 
    df,
    get_position=["longitude", "latitude"],
    get_color=[255, 0, 0, 160],  
    get_radius=1000,  
    pickable=True
)

# %%
view_state = pdk.ViewState(
    latitude=31.0461, 
    longitude=34.8516,  
    zoom=7, 
    bearing=0,
    pitch=45
)
r = pdk.Deck(
    layers=[layer],
    initial_view_state=view_state,
)
r.to_html("map.html")
# Out:
#         <iframe
#             width="100%"
#             height=500
#             frameborder="0"
#             srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
#   &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;title&gt;pydeck&lt;/title&gt;
#         &lt;script src=&quot;https://api.tiles.mapbox.com/mapbox-gl-js/v1.13.0/mapbox-gl.js&quot;&gt;&lt;/script&gt;
#         &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot; /&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot; /&gt;
#     &lt;script src=&#x27;https://cdn.jsdelivr.net/npm/@deck.gl/jupyter-widget@~8.8.*/dist/index.js&#x27;&gt;&lt;/script&gt;
#     &lt;style&gt;
#     body {
#   margin: 0;
#   padding: 0;
#   overflow: hidden;
# }
#
# #deck-container {
#   width: 100vw;
#   height: 100vh;
# }
#
# #deck-container canvas {
#   z-index: 1;
#   background: none;
# }
#     &lt;/style&gt;
#   &lt;/head&gt;
#   &lt;body&gt;
#     &lt;div id=&quot;deck-container&quot;&gt;
#     &lt;/div&gt;
#   &lt;/body&gt;
#   &lt;script&gt;
#     const container = document.getElementById(&#x27;deck-container&#x27;);
#     const jsonInput = {
#   &quot;initialViewState&quot;: {
#     &quot;bearing&quot;: 0,
#     &quot;latitude&quot;: 31.0461,
#     &quot;longitude&quot;: 34.8516,
#     &quot;pitch&quot;: 45,
#     &quot;zoom&quot;: 7
#   },
#   &quot;layers&quot;: [
#     {
#       &quot;@@type&quot;: &quot;ScatterplotLayer&quot;,
#       &quot;data&quot;: [
#         {
#           &quot;attack_indicator&quot;: 1,
#           &quot;latitude&quot;: 31.771599,
#           &quot;longitude&quot;: 35.2034,
#           &quot;nkill&quot;: 1
#         },
#         {
#           &quot;attack_indicator&quot;: 1,
#           &quot;latitude&quot;: 32.004361,
#           &quot;longitude&quot;: 34.888229,
#           &quot;nkill&quot;: 26
#         },
#         {
#           &quot;attack_indicator&quot;: 1,
#           &quot;latitude&quot;: 31.771599,
#           &quot;longitude&quot;: 35.2034,
#           &quot;nkill&quot;: 0
#         },
#         {
#           &quot;attack_indicator&quot;: 1,
#           &quot;latitude&quot;: 31.771599,
#           &quot;longitude&quot;: 35.2034,
#           &quot;nkill&quot;: 0
#         },
#         {
#           &quot;attack_indicator&quot;: 1,
#           &quot;latitude&quot;: 31.771599,
#           &quot;longitude&quot;: 35.2034,
#           &quot;nkill&quot;: 0
#         },
#         {
#           &quot;attack_indicator&quot;: 1,
#           &quot;latitude&quot;: 31.771599,
#           &quot;longitude&quot;: 35.2034,
#           &quot;nkill&quot;: 0
#         },
#         {
#           &quot;attack_indicator&quot;: 1,
#           &quot;latitude&quot;: 31.771599,
#           &quot;longitude&quot;: 35.2034,
#           &quot;nkill&quot;: 0
#         },
#         {
#           &quot;attack_indicator&quot;: 1,
#           &quot;latitude&quot;: 31.771599,
#           &quot;longitude&quot;: 35.2034,
#           &quot;nkill&quot;: 0
#         },
#         {
#           &quot;attack_indicator&quot;: 1,
#           &quot;latitude&quot;: 31.771599,
#           &quot;longitude&quot;: 35.2034,
#           &quot;nkill&quot;: 0
#         },
#         {
#           &quot;attack_indicator&quot;: 1,
#           &quot;latitude&quot;: 31.771599,
#           &quot;longitude&quot;: 35.2034,
#           &quot;nkill&quot;: 0
#         },
#         {
#           &quot;attack_indicator&quot;: 1,
#           &quot;latitude&quot;: 31.771599,
#           &quot;longitude&quot;: 35.2034,
#           &quot;nkill&quot;: 0
#         },
#         {
#           &quot;attack_indicator&quot;: 1,
#           &quot;latitude&quot;: 31.771599,
#           &quot;longitude&quot;: 35.2034,
#           &quot;nkill&quot;: 0
#         },
#         {
#           &quot;attack_indicator&quot;: 1,
#           &quot;latitude&quot;: 31.771599,
#           &quot;longitude&quot;: 35.2034,
#           &quot;nkill&quot;: 0
#         },
#         {
#           &quot;attack_indicator&quot;: 1,
#           &quot;latitude&quot;: 31.771599,
#           &quot;longitude&quot;: 35.2034,
#           &quot;nkill&quot;: 0
#         },
#         {
#           &quot;attack_indicator&quot;: 1,
#           &quot;latitude&quot;: 31.771599,
#           &quot;longitude&quot;: 35.2034,
#           &quot;nkill&quot;: 0
#         },
#         {
#           &quot;attack_indicator&quot;: 1,
#           &quot;latitude&quot;: 31.771599,
#           &quot;longitude&quot;: 35.2034,
#           &quot;nkill&quot;: 0
#         },
#         {
#           &quot;attack_indicator&quot;: 1,
#           &quot;latitude&quot;: 31.771599,
#           &quot;longitude&quot;: 35.2034,
#           &quot;nkill&quot;: 2
#         },
#         {
#           &quot;attack_indicator&quot;: 1,
#           &quot;latitude&quot;: 31.771599,
#           &quot;longitude&quot;: 35.2034,
#           &quot;nkill&quot;: 0
#         },
#         {
#           &quot;attack_indicator&quot;: 1,
#           &quot;latitude&quot;: 31.771599,
#           &quot;longitude&quot;: 35.2034,
#           &quot;nkill&quot;: 0
#         },
#         {
#           &quot;attack_indicator&quot;: 1,
#           &quot;latitude&quot;: 31.771599,
#           &quot;longitude&quot;: 35.2034,
#           &quot;nkill&quot;: 0
#         },
#         {
#           &quot;attack_indicator&quot;: 1,
#           &quot;latitude&quot;: 33.208509,
#           &quot;longitude&quot;: 35.570348,
#           &quot;nkill&quot;: 21
#         },
#         {
#           &quot;attack_indicator&quot;: 1,
#           &quot;latitude&quot;: 33.014797,
#           &quot;longitude&quot;: 35.275805,
#           &quot;nkill&quot;: 25
#         },
#         {
#           &quot;attack_indicator&quot;: 1,
#           &quot;latitude&quot;: 33.166809,
#           &quot;longitude&quot;: 35.659965,
#           &quot;nkill&quot;: 7
#         },
#         {
#           &quot;attack_indicator&quot;: 1,
#           &quot;latitude&quot;: 33.004219,
#           &quot;longitude&quot;: 35.092571,
#           &quot;nkill&quot;: 14
#         },
#         {
#           &quot;attack_indicator&quot;: 1,
#           &quot;latitude&quot;: 32.496086,
#           &quot;longitude&quot;: 35.498352,
#           &quot;nkill&quot;: 7
#         },
#         {
#           &quot;attack_indicator&quot;: 1,
#           &quot;latitude&quot;: 33.04924,
#           &quot;longitude&quot;: 35.4882,
#           &quot;nkill&quot;: 1
#         },
#         {
#           &quot;attack_indicator&quot;: 1,
#           &quot;latitude&quot;: 33.085678,
#           &quot;longitude&quot;: 35.113181,
#           &quot;nkill&quot;: 1
#         },
#         {
#           &quot;attack_indicator&quot;: 1,
#           &quot;latitude&quot;: 32.08297,
#           &quot;longitude&quot;: 34.811886,
#           &quot;nkill&quot;: 2
#         },
#         {
#           &quot;attack_indicator&quot;: 1,
#           &quot;latitude&quot;: 31.771599,
#           &quot;longitude&quot;: 35.2034,
#           &quot;nkill&quot;: 0
#         },
#         {
#           &quot;attack_indicator&quot;: 1,
#           &quot;latitude&quot;: 32.08297,
#           &quot;longitude&quot;: 34.811886,
#           &quot;nkill&quot;: 18
#         },
#         {
#           &quot;attack_indicator&quot;: 1,
#           &quot;latitude&quot;: 31.771599,
#           &quot;longitude&quot;: 35.2034,
#           &quot;nkill&quot;: 6
#         },
#         {
#           &quot;attack_indicator&quot;: 1,
#           &quot;latitude&quot;: 31.771599,
#           &quot;longitude&quot;: 35.2034,
#           &quot;nkill&quot;: 0
#         },
#         {
#           &quot;attack_indicator&quot;: 1,
#           &quot;latitude&quot;: 31.771599,
#           &quot;longitude&quot;: 35.2034,
#           &quot;nkill&quot;: 1
#         },
#         {
#           &quot;attack_indicator&quot;: 1,
#           &quot;latitude&quot;: 31.771599,
#           &quot;longitude&quot;: 35.2034,
#           &quot;nkill&quot;: 0
#         },
#         {
#           &quot;attack_indicator&quot;: 1,
#           &quot;latitude&quot;: 31.248484,
#           &quot;longitude&quot;: 34.787853,
#           &quot;nkill&quot;: 0
#         },
#         {
#           &quot;attack_indicator&quot;: 1,
#           &quot;latitude&quot;: 31.771599,
#           &quot;lo

# %%
attacks_per_location = df.groupby(['latitude', 'longitude']).size().reset_index(name='counts')

map_attacks = folium.Map(location=[df['latitude'].mean(), df['longitude'].mean()], zoom_start=8)
HeatMap(data=attacks_per_location[['latitude', 'longitude', 'counts']].values.tolist(), radius=15).add_to(map_attacks)

map_attacks
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d12402158a24e494dd466fe2c6631082 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium@main/folium/templates/leaflet_heat.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d12402158a24e494dd466fe2c6631082&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d12402158a24e494dd466fe2c6631082 = L.map(
#                 &quot;map_d12402158a24e494dd466fe2c6631082&quot;,
#                 {
#                     center: [31.80779216625433, 34.8982099559624],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 8,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7bb10d49b9fde6efcaa6766c7e2466e9 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_7bb10d49b9fde6efcaa6766c7e2466e9.addTo(map_d12402158a24e494dd466fe2c6631082);
#
#
#             var heat_map_46e2b505e240eab0224e6b809b7244e4 = L.heatLayer(
#                 [[29.554548, 34.947531, 12.0], [29.554548, 34.947533, 7.0], [30.281462, 34.957573, 1.0], [30.358333, 34.651389, 1.0], [30.449667, 35.053592, 1.0], [30.491551, 35.165443, 1.0], [30.495131, 34.559644, 1.0], [30.66667, 34.83333, 17.0], [30.683672, 34.86581, 1.0], [30.714086, 34.875748, 1.0], [30.721449, 34.875657, 1.0], [30.754884, 34.857392, 1.0], [30.792205, 34.472404, 1.0], [30.812962, 34.908973, 1.0], [30.824685, 34.921618, 1.0], [30.829561, 35.038816, 1.0], [30.829562, 35.038816, 36.0], [30.833017, 35.042271, 3.0], [30.860711, 34.821861, 1.0], [30.873715, 34.792986, 1.0], [30.894752, 34.450112, 1.0], [30.894753, 34.450111, 1.0], [30.906518, 34.81435, 1.0], [30.933888, 35.378208, 1.0], [31.019476, 34.590935, 1.0], [31.020947, 34.820005, 1.0], [31.046051, 34.851612, 1.0], [31.058238, 34.854346, 1.0], [31.070501, 35.030529, 7.0], [31.070501, 35.03053, 3.0], [31.098334, 34.749311, 1.0], [31.137357, 34.826976, 1.0], [31.189301, 34.319349, 1.0], [31.192114, 34.449473, 30.0], [31.198501, 34.405786, 1.0], [31.199311, 34.839938, 1.0], [31.202322, 34.464182, 1.0], [31.202661, 34.
.428993, 34.460874, 1.0], [31.429092, 34.513202, 1.0], [31.431391, 34.537143, 1.0], [31.435217, 34.43649, 1.0], [31.442023, 34.580891, 1.0], [31.445328, 34.66842, 1.0], [31.450878, 34.546573, 1.0], [31.451986, 35.384288, 1.0], [31.453035, 34.465514, 3.0], [31.459133, 34.624161, 1.0], [31.470289, 34.593106, 1.0], [31.470321, 34.53545, 1.0],

# %%
kills_per_location = df.groupby(['latitude', 'longitude'])['nkill'].sum().reset_index()

map_kills = folium.Map(location=[df['latitude'].mean(), df['longitude'].mean()], zoom_start=8)
HeatMap(data=kills_per_location[['latitude', 'longitude', 'nkill']].values.tolist(), radius=15).add_to(map_kills)

map_kills
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8d3eefaf140dad4183ce882b3579f803 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium@main/folium/templates/leaflet_heat.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8d3eefaf140dad4183ce882b3579f803&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_8d3eefaf140dad4183ce882b3579f803 = L.map(
#                 &quot;map_8d3eefaf140dad4183ce882b3579f803&quot;,
#                 {
#                     center: [31.80779216625433, 34.8982099559624],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 8,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_5da9bf4e8693aaecc7d9e70971e8b26f = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_5da9bf4e8693aaecc7d9e70971e8b26f.addTo(map_8d3eefaf140dad4183ce882b3579f803);
#
#
#             var heat_map_ad941adb5095fc68bf256e49a7cdd064 = L.heatLayer(
#                 [[29.554548, 34.947531, 0.0], [29.554548, 34.947533, 24.0], [30.281462, 34.957573, 0.0], [30.358333, 34.651389, 0.0], [30.449667, 35.053592, 0.0], [30.491551, 35.165443, 0.0], [30.495131, 34.559644, 4.0], [30.66667, 34.83333, 4.0], [30.683672, 34.86581, 0.0], [30.714086, 34.875748, 0.0], [30.721449, 34.875657, 0.0], [30.754884, 34.857392, 0.0], [30.792205, 34.472404, 3.0], [30.812962, 34.908973, 0.0], [30.824685, 34.921618, 0.0], [30.829561, 35.038816, 0.0], [30.829562, 35.038816, 16.0], [30.833017, 35.042271, 0.0], [30.860711, 34.821861, 0.0], [30.873715, 34.792986, 0.0], [30.894752, 34.450112, 0.0], [30.894753, 34.450111, 1.0], [30.906518, 34.81435, 0.0], [30.933888, 35.378208, 0.0], [31.019476, 34.590935, 0.0], [31.020947, 34.820005, 0.0], [31.046051, 34.851612, 0.0], [31.058238, 34.854346, 0.0], [31.070501, 35.030529, 3.0], [31.070501, 35.03053, 1.0], [31.098334, 34.749311, 0.0], [31.137357, 34.826976, 0.0], [31.189301, 34.319349, 0.0], [31.192114, 34.449473, 5.0], [31.198501, 34.405786, 0.0], [31.199311, 34.839938, 0.0], [31.202322, 34.464182, 0.0], [31.202661, 34.466578, 0.0], [31.204293, 34.465897, 0.0], [31.204947, 34.465511, 0.0], [31.205791, 34.463728, 0.0], [31.205826, 34.462316, 0.0], [31.206242, 34.464335, 0.0], [31.206525, 34.46519, 0.0], [31.20666, 34.46471, 0.0], [31.206705, 34.464343, 0.0], [31.206808, 34.464185, 5.0], [31.206913, 34.464007, 0.0], [31.207187, 34.413553, 0.0], [31.20772, 34.465326,